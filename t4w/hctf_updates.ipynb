# %% [markdown]
# **Data preparation**

# %%
import warnings
warnings.simplefilter(action='ignore')

import os
import arcpy
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
wks= r'Q:\dss_workarea\mlabiadh\workspace\20250505_t4w_hctf_updates'
gdb = r'Q:\projects\Mflnro\Together_for_Wildlife_Funding_Dashboard\outputs\final_data.gdb'

# %%
gdf_pnts = gpd.read_file(
    gdb,
    layer='T4W_Goal_Action_points_with_Attributes',
    driver='OpenFileGDB',
)

df_pnts= gdf_pnts.drop(columns=['geometry'])

# %%
df =  pd.read_excel(
    os.path.join(wks, 'May20th2025_T4W_Goal_Actions_HCTF_edited.xlsx'),
)
df= df.drop(columns=['Comments'])

# %%
# This checks if the Project_ID already starts with a year pattern (4 digits followed by a dash)
condition = ~df['Project_ID'].str.match(r'^\d{4}-')

# Apply the concatenation only to records where the Project_ID doesn't already have year info
df.loc[condition, 'Project_ID'] = df.loc[condition, 'Year'].astype(str) + '-' + df.loc[condition, 'Project_ID'].astype(str)


df['Action'] = df['Action'].replace(
    'Action 9 - On-the-ground',
    'Action 09 - On-the-ground Action'
)

# %%
mask = (
    df_pnts['Project_ID'].str.lower().str.contains('hctf', na=False)
    | df_pnts['Project_Type'].eq('HCTF')
)

df_pnts_hctf = df_pnts[mask]

# %%
#missing projects
missing_ids = df_pnts_hctf.loc[~df_pnts_hctf['Project_ID'].isin(df['Project_ID']), 'Project_ID'].dropna().unique()
list(missing_ids)
# Out:
# ['2024-T4W-HCTF39', '2024-T4W-HCTF38']

# %%
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]

gdf = (
    gpd.GeoDataFrame(
        df,
        geometry=geometry,
        crs="EPSG:4326"
    )
    .to_crs("EPSG:3005")
)

# %% [markdown]
# **Update the Points featureclass**

# %%
#fc = r'Q:\dss_workarea\mlabiadh\workspace\20250505_t4w_hctf_updates\test_data.gdb\t4w_points_data_test'
fc = os.path.join(gdb,'T4W_Goal_Action_points_with_Attributes')

key='Project_ID'

# index GeoDataFrame by key for fast lookups
gdf_indexed = gdf.set_index(key)

# pick all fields except OID, Geometry, and the key
fields = [
    f.name for f in arcpy.ListFields(fc)
    if f.type not in ('OID', 'Geometry') and f.name != key
]
fields.append('SHAPE@')  # token for geometry

# get the feature class’s spatial reference
sr = arcpy.Describe(fc).spatialReference

updated_ids = []
inserted_ids = []
unmatched = set(gdf_indexed.index)

# 1) Update existing rows
with arcpy.da.UpdateCursor(fc, [key] + fields) as cursor:
    for row in cursor:
        pid = row[0]
        if pid in gdf_indexed.index:
            rec = gdf_indexed.loc[pid]
            for i, fld in enumerate(fields, start=1):
                if fld == 'SHAPE@':
                    # build ArcPy geometry from WKT
                    row[i] = arcpy.FromWKT(rec.geometry.wkt, sr)
                else:
                    row[i] = rec[fld]
            cursor.updateRow(row)
            updated_ids.append(pid)
            unmatched.discard(pid)

# 2) Insert new rows for everything still unmatched
if unmatched:
    insert_fields = [key] + fields
    with arcpy.da.InsertCursor(fc, insert_fields) as icursor:
        for pid in unmatched:
            rec = gdf_indexed.loc[pid]
            new_row = [None] * len(insert_fields)
            new_row[0] = pid
            for i, fld in enumerate(fields, start=1):
                if fld == 'SHAPE@':
                    new_row[i] = arcpy.FromWKT(rec.geometry.wkt, sr)
                else:
                    new_row[i] = rec[fld]
            icursor.insertRow(new_row)
            inserted_ids.append(pid)

# %% [markdown]
# **Data Publishing**

# %%
from arcgis.gis import GIS
import time
import json

# %%
key='Project_ID'
agol_item_id = '196b5b06452643e4a80408d0c28b5e06'


gis = GIS(
    'https://governmentofbc.maps.arcgis.com', 
    'PX.GeoBC.DSS.Creator', 
    'maps_are_gr8!', 
    verify_cert=False

) 


print(f"..retrieving target layer with ID: {agol_item_id}")
item = gis.content.get(agol_item_id)
if not item:
    raise ValueError(f"Feature layer with ID {agol_item_id} not found.")

layer = item.layers[0]  
print(f"..found feature layer: {item.title}")

total_rows = int(arcpy.GetCount_management(fc)[0])
print(f"..source feature class contains {total_rows} rows")

print("..truncating the feature layer...")
layer.manager.truncate()
print("..feature layer truncated successfully.")

# determine which fields to upload
fields = [
    f.name for f in arcpy.ListFields(fc)
    if f.name in gdf.columns and f.type not in ("OID", "Geometry")
]

# build the search cursor
search_fields = ["SHAPE@"] + fields
failed_ids = []

print("..uploading records one by one...")
with arcpy.da.SearchCursor(fc, search_fields, "1=1") as cursor:
    for row in cursor:
        geom = row[0]
        if geom is None:
            print("..skipping record with no geometry")
            continue

        # build the attributes dict
        attrs = {fields[i]: row[i + 1] for i in range(len(fields))}
        unique_id = attrs['Project_ID']

        feature = {
            "geometry": json.loads(geom.JSON),
            "attributes": attrs
        }

        # try to add the single feature
        try:
            result = layer.edit_features(adds=[feature])
            add_res = result.get("addResults", [])
            if not add_res or not add_res[0].get("success", False):
                raise RuntimeError(add_res[0].get("error", "Unknown error"))
            print(f"..successfully added record {unique_id}")
        except Exception as e:
            print(f"..FAILED to add record {unique_id}: {e}")
            failed_ids.append(unique_id)

        # small pause to avoid hammering the service
        time.sleep(1)

if failed_ids:
    print(f"\n..upload complete with failures ({len(failed_ids)}): {failed_ids}")
else:
    print("\n..all records uploaded successfully.")
# Out:
# Setting `verify_cert` to False is a security risk, use at your own risk.
# ..retrieving target layer with ID: 196b5b06452643e4a80408d0c28b5e06
# ..found feature layer: Together_for_Wildlife_Funding_L1A_Feature_Layer_Project_Clusters
# ..source feature class contains 476 rows
# ..truncating the feature layer...
# ..feature layer truncated successfully.
# ..uploading records one by one...
# ..successfully added record 2022-T4W274
# ..successfully added record 2022-T4W240
# ..successfully added record 2022-T4W213
# ..successfully added record 2022-T4W271
# ..successfully added record 2022-T4W215
# ..successfully added record 2022-T4W228
# ..successfully added record 2022-T4W253
# ..successfully added record 2022-T4W242
# ..successfully added record 2022-T4W208
# ..successfully added record 2022-T4W210
# ..successfully added record 2022-T4W230
# ..successfully added record 2022-T4W264
# ..successfully added record 2022-T4W227
# ..successfully added record 2022-T4W223
# ..successfully added record 2022-T4W237
# ..successfully added record 2022-T4W205
# ..successfully added record 2022-T4W221
# ..successfully added record 2022-T4W232
# ..successfully added record 2022-T4W269
# ..successfully added record 2022-T4W300
# ..successfully added record 2022-T4W214
# ..successfully added record 2022-T4W229
# ..successfully added record 2022-T4W235
# ..successfully added record 2022-T4W234
# ..successfully added record 2022-T4W207
# ..successfully added record 2022-T4W268
# ..successfully added record 2022-T4W238
# ..successfully added record 2022-T4W226
# ..successfully added record 2022-T4W254
# ..successfully added record 2022-T4W204
# ..successfully added record 2022-T4W200
# ..successfully added record 2022-T4W231
# ..successfully added record 2022-T4W222
# ..successfully added record 2022-T4W257
# ..successfully added record 2022-T4W236
# ..successfully added record 2022-T4W256
# ..successfully added record 2022-T4W281
# ..successfully added record 2022-T4W225
# ..successfully added record 2022-T4W247
# ..successfully added record 2022-T4W267
# ..successfully added record 2022-T4W211
# ..successfully added record 2022-T4W258
# ..successfully added record 2022-T4W250
# ..successfully added record 2022-T4W260
# ..successfully added record 2022-T4W251
# ..successfully added record 2022-T4W259
# ..successfully added record 2022-T4W220
# ..successfully added record 2022-T4W262
# ..successfully added record 2022-T4W224
# ..successfully added record 2022-T4W239
# ..successfully added record 2022-T4W201
# ..successfully added record 2022-T4W255
# ..successfully added record 2022-T4W270
# ..successfully added record 2022-T4W263
# ..successfully added record 2022-T4W337
# ..successfully added record 2022-T4W338
# ..successfully added record 2022-T4W339
# ..successfully added record 2022-T4W272
# ..successfully added record 2022-T4W286
# ..successfully added record 2022-T4W243
# ..successfully added record 2022-T4W316
# ..successfully added record 2022-T4W326
# ..successfully added record 2022-T4W246
# ..successfully added record 2022-T4W317
# ..successfully added record 2022-T4W261
# ..successfully added record 2022-T4W320
# ..successfully added record 2022-T4W252
# ..successfully added record 2022-T4W323
# ..successfully added record 2022-T4W325
# ..successfully added record 2022-T4W275
# ..successfully added record 2022-T4W245
# ..successfully added record 2022-T4W244
# ..successfully added record 2022-T4W307
# ..successfully added record 2022-T4W327
# ..successfully added record 2022-T4W328
# ..successfully added record 2022-T4W295
# ..successfully added record 2022-T4W279
# ..successfully added record 2022-T4W298
# ..successfully added record 2022-T4W331
# ..successfully added record 2022-T4W315
# ..successfully added record 2022-T4W324
# ..successfully added record 2022-T4W218
# ..successfully added record 2022-T4W303
# ..successfully added record 2022-T4W304
# ..successfully added record 2022-T4W306
# ..successfully added record 2022-T4W322
# ..successfully added record 2022-T4W206
# ..successfully added record 2022-T4W203
# ..successfully added record 2022-T4W202
# ..successfully added record 2022-T4W312
# ..successfully added record 2021-T4W0129
# ..successfully added record 2021-T4W130
# ..successfully added record 2021-T4W057
# ..successfully added record 2021-T4W056
# ..successfully added record 2021-T4W054
# ..successfully added record 2021-T4W0112
# ..successfully added record 2021-T4W053
# ..successfully added record 2021-T4W055
# ..successfully added record 2021-T4W002
# ..successfully added record 2021-T4W003
# ..successfully added record 2021-T4W041
# ..successfully added record 2021-T4W0118
# ..successfully added record 2021-T4W042
# ..successfully added record 2021-T4W0113
# ..successfully added record 2021-T4W040
# ..successfully added record 2021-T4W0119
# ..successfully added record 2021-T4W0114
# ..successfully added record 2021-T4W012
# ..successfully added record 2021-T4W0117
# ..successfully added record 2021-T4W0116
# ..successfully added record 2021-T4W0115
# ..successfully added record 2021-T4W0124
# ..successfully added record 2021-T4W039
# ..successfully added record 2021-T4W0123
# ..successfully added record 2021-T4W011
# ..successfully added record 2021-T4W0127
# ..successfully added record 2021-T4W097a
# ..successfully added record 2021-T4W0122
# ..successfully added record 2021-T4W089
# ..successfully added record 2021-T4W0120
# ..successfully added record 2021-T4W0121
# ..successfully added record 2021-T4W0125
# ..successfully added record 2021-T4W0134
# ..successfully added record 2021-T4W0128
# ..successfully added record 2021-T4W132
# ..successfully added record 2021-T4W131
# ..successfully added record 2021-T4W133
# ..successfully added record 2021-T4W007
# ..successfully added record 2021-T4W006
# ..successfully added record 2021-T4W091
# ..successfully added record 2021-T4W084
# ..successfully added record 2021-T4W0111
# ..successfully added record 2021-T4W038
# ..successfully added record 2021-T4W036
# ..successfully added record 2021-T4W023
# ..successfully added record 2021-T4W035
# ..successfully added record 2021-T4W037
# ..successfully added record 2021-T4W014
# ..successfully added record 2021-T4W013
# ..successfully added record 2021-T4W016
# ..successfully added record 2021-T4W048
# ..successfully added record 2021-T4W027
# ..successfully added record 2021-T4W017
# ..successfully added record 2021-T4W019
# ..successfully added record 2021-T4W020
# ..successfully added record 2021-T4W034
# ..successfully added record 2021-T4W033
# ..successfully added record 2021-T4W018
# ..successfully added record 2021-T4W031
# ..successfully added record 2021-T4W028
# ..successfully added record 2021-T4W029
# ..successfully added record 2021-T4W030
# ..successfully added record 2021-T4W032
# ..successfully added record 2021-T4W026
# ..successfully added record 2021-T4W022
# ..successfully added record 2021-T4W021
# ..successfully added record 2021-T4W047
# ..successfully added record 2021-T4W046
# ..successfully added record 2021-T4W009
# ..successfully added record 2021-T4W015
# ..successfully added record 2021-T4W024
# ..successfully added record 2021-T4W008
# ..successfully added record 2021-T4W025
# ..successfully added record 2021-T4W0106
# ..successfully added record 2021-T4W045
# ..successfully added record 2021-T4W044
# ..successfully added record 2021-T4W010
# ..successfully added record 2021-T4W043
# ..successfully added record 2021-T4W050
# ..successfully added record 2021-T4W005
# ..successfully added record 2021-T4W052
# ..successfully added record 2021-T4W051
# ..successfully added record 2021-T4W076
# ..successfully added record 2021-T4W081
# ..successfully added record 2021-T4W093
# ..successfully added record 2021-T4W094
# ..successfully added record 2021-T4W068
# ..successfully added record 2021-T4W071
# ..successfully added record 2021-T4W0109
# ..successfully added record 2021-T4W070
# ..successfully added record 2021-T4W061
# ..successfully added record 2021-T4W069
# ..successfully added record 2021-T4W085
# ..successfully added record 2021-T4W087
# ..successfully added record 2021-T4W086
# ..successfully added record 2021-T4W088
# ..successfully added record 2021-T4W079
# ..successfully added record 2021-T4W078
# ..successfully added record 2021-T4W0108
# ..successfully added record 2021-T4W080
# ..successfully added record 2021-T4W062
# ..successfully added record 2021-T4W064
# ..successfully added record 2021-T4W065
# ..successfully added record 2021-T4W0105
# ..successfully added record 2021-T4W067
# ..successfully added record 2021-T4W083
# ..successfully added record 2021-T4W063
# ..successfully added record 2021-T4W082
# ..successfully added record 2021-T4W0104
# ..successfully added record 2021-T4W066
# ..successfully added record 2021-T4W101
# ..successfully added record 2021-T4W077
# ..successfully added record 2021-T4W004
# ..successfully added record 2021-T4W097
# ..successfully added record 2021-T4W060
# ..successfully added record 2021-T4W099
# ..successfully added record 2021-T4W098
# ..successfully added record 2021-T4W059
# ..successfully added record 2021-T4W096
# ..successfully added record 2021-T4W095
# ..successfully added record 2021-T4W100
# ..successfully added record 2021-T4W0103
# ..successfully added record 2021-T4W0102
# ..successfully added record 2021-T4W075
# ..successfully added record 2021-T4W074
# ..successfully added record 2021-T4W0107
# ..successfully added record 2021-T4W072
# ..successfully added record 2021-T4W073
# ..successfully added record 2021-T4W000
# ..successfully added record 2022-T4W219
# ..successfully added record 2022-T4W-HCTF01
# ..successfully added record 2022-T4W-HCTF02
# ..successfully added record 2022-T4W-HCTF04
# ..successfully added record 2022-T4W-HCTF05
# ..successfully added record 2022-T4W-HCTF06
# ..successfully added record 2022-T4W-HCTF07
# ..successfully added record 2022-T4W-HCTF08
# ..successfully added record 2022-T4W-HCTF09
# ..successfully added record 2022-T4W-HCTF10
# ..successfully added record 2022-T4W-HCTF11
# ..successfully added record 2022-T4W-HCTF12
# ..successfully added record 2022-T4W-HCTF03
# ..successfully added record 2022-T4W000
# ..successfully added record 2022-T4W340
# ..successfully added record 2022-T4W233
# ..successfully added record 2022-T4W212
# ..successfully added record 2022-T4W209
# ..successfully added record 2023-T4W-017
# ..successfully added record 2023-T4W-018
# ..successfully added record 2023-T4W-019
# ..successfully added record 2023-T4W-020
# ..successfully added record 2023-T4W-021
# ..successfully added record 2023-T4W-022
# ..successfully added record 2023-T4W-023
# ..successfully added record 2023-T4W-024
# ..successfully added record 2023-T4W-025
# ..successfully added record 2023-T4W-026
# ..successfully added record 2023-T4W-027
# ..successfully added record 2023-T4W-028
# ..successfully added record 2023-T4W-029
# ..successfully added record 2023-T4W-030
# ..successfully added record 2023-T4W-034
# ..successfully added record 2023-T4W-041
# ..successfully added record 2023-T4W-042
# ..successfully added record 2023-T4W-043
# ..successfully added record 2023-T4W-046
# ..successfully added record 2023-T4W-049
# ..successfully added record 2023-T4W-056
# ..successfully added record 2023-T4W-062
# ..successfully added record 2023-T4W-064
# ..successfully added record 2023-T4W-065
# ..successfully added record 2023-T4W-066
# ..successfully added record 2023-T4W-068
# ..successfully added record 2023-T4W-070
# ..successfully added record 2023-T4W-071
# ..successfully added record 2023-T4W-072
# ..successfully added record 2023-T4W-073
# ..successfully added record 2023-T4W-074
# ..successfully added record 2023-T4W-077
# ..successfully added record 2023-T4W-078
# ..successfully added record 2023-T4W-079
# ..successfully added record 2023-T4W-080
# ..successfully added record 2023-T4W-082
# ..successfully added record 2023-T4W-083
# ..successfully added record 2023-T4W-084
# ..successfully added record 2023-T4W-085
# ..successfully added record 2023-T4W-087
# ..successfully added record 2023-T4W-088
# ..successfully added record 2023-T4W-090
# ..successfully added record 2023-T4W-091
# ..successfully added record 2023-T4W-092
# ..successfully added record 2023-T4W-093
# ..successfully added record 2023-T4W-098
# ..successfully added record 2023-T4W-099
# ..successfully added record 2023-T4W-100
# ..successfully added record 2023-T4W-102
# ..successfully added record 2023-T4W-117
# ..successfully added record 2023-T4W-119
# ..successfully added record 2023-T4W-001
# ..successfully added record 2023-T4W-005
# ..successfully added record 2023-T4W-008
# ..successfully added record 2023-T4W-009
# ..successfully added record 2023-T4W-010
# ..successfully added record 2023-T4W-011
# ..successfully added record 2023-T4W-012
# ..successfully added record 2023-T4W-013
# ..successfully added record 2023-T4W-016
# ..successfully added record 2023-T4W-031
# ..successfully added record 2023-T4W-032
# ..successfully added record 2023-T4W-033
# ..successfully added record 2023-T4W-035
# ..successfully added record 2023-T4W-036
# ..successfully added record 2023-T4W-037
# ..successfully added record 2023-T4W-038
# ..successfully added record 2023-T4W-039
# ..successfully added record 2023-T4W-040
# ..successfully added record 2023-T4W-045
# ..successfully added record 2023-T4W-047
# ..successfully added record 2023-T4W-048
# ..successfully added record 2023-T4W-050
# ..successfully added record 2023-T4W-052
# ..successfully added record 2023-T4W-053
# ..successfully added record 2023-T4W-054
# ..successfully added record 2023-T4W-055
# ..successfully added record 2023-T4W-057
# ..successfully added record 2023-T4W-058
# ..successfully added record 2023-T4W-059
# ..successfully added record 2023-T4W-060
# ..successfully added record 2023-T4W-061
# ..successfully added record 2023-T4W-063
# ..successfully added record 2023-T4W-067
# ..successfully added record 2023-T4W-075
# ..successfully added record 2023-T4W-076
# ..successfully added record 2023-T4W-086
# ..successfully added record 2023-T4W-089
# ..successfully added record 2023-T4W-094
# ..successfully added record 2023-T4W-095
# ..successfully added record 2023-T4W-096
# ..successfully added record 2023-T4W-101
# ..successfully added record 2023-T4W-103
# ..successfully added record 2023-T4W-105
# ..successfully added record 2023-T4W-106
# ..successfully added record 2023-T4W-109
# ..successfully added record 2023-T4W-112
# ..successfully added record 2023-T4W-113
# ..successfully added record 2023-T4W-114
# ..successfully added record 2023-T4W-115
# ..successfully added record 2023-T4W-120
# ..successfully added record 2023-T4W-121
# ..successfully added record 2023-T4W-123
# ..successfully added record 2023-T4W-122
# ..successfully added record 2024-T4W-000
# ..successfully added record 2024-T4W-002
# ..successfully added record 2024-T4W-003
# ..successfully added record 2024-T4W-004
# ..successfully added record 2024-T4W-005
# ..successfully added record 2024-T4W-006
# ..successfully added record 2024-T4W-007
# ..successfully added record 2024-T4W-009
# ..successfully added record 2024-T4W-010
# ..successfully added record 2024-T4W-011
# ..successfully added record 2024-T4W-012
# ..successfully added record 2024-T4W-013
# ..successfully added record 2024-T4W-014
# ..successfully added record 2024-T4W-015
# ..successfully added record 2024-T4W-016
# ..successfully added record 2024-T4W-017
# ..successfully added record 2024-T4W-018
# ..successfully added record 2024-T4W-019
# ..successfully added record 2024-T4W-020
# ..successfully added record 2024-T4W-021
# ..successfully added record 2024-T4W-022
# ..successfully added record 2024-T4W-023
# ..successfully added record 2024-T4W-024
# ..successfully added record 2024-T4W-025
# ..successfully added record 2024-T4W-026
# ..successfully added record 2024-T4W-027
# ..successfully added record 2024-T4W-028
# ..successfully added record 2024-T4W-029
# ..successfully added record 2024-T4W-031
# ..successfully added record 2024-T4W-032
# ..successfully added record 2024-T4W-033
# ..successfully added record 2024-T4W-034
# ..successfully added record 2024-T4W-035
# ..successfully added record 2024-T4W-036
# ..successfully added record 2024-T4W-037
# ..successfully added record 2024-T4W-038
# ..successfully added record 2024-T4W-039
# ..successfully added record 2024-T4W-040
# ..successfully added record 2024-T4W-041
# ..successfully added record 2024-T4W-043
# ..successfully added record 2024-T4W-044
# ..successfully added record 2024-T4W-045
# ..successfully added record 2024-T4W-046
# ..successfully added record 2024-T4W-047
# ..successfully added record 2024-T4W-048
# ..successfully added record 2024-T4W-049
# ..successfully added record 2024-T4W-050
# ..successfully added record 2024-T4W-053
# ..successfully added record 2024-T4W-054
# ..successfully added record 2024-T4W-055
# ..successfully added record 2024-T4W-056
# ..successfully added record 2024-T4W-057
# ..successfully added record 2024-T4W-058
# ..successfully added record 2024-T4W-059
# ..successfully added record 2024-T4W-060
# ..successfully added record 2024-T4W-061
# ..successfully added record 2024-T4W-062
# ..successfully added record 2024-T4W-063
# ..successfully added record 2024-T4W-064
# ..successfully added record 2024-T4W-065
# ..successfully added record 2024-T4W-066
# ..successfully added record 2024-T4W-067
# ..successfully added record 2024-T4W-068
# ..successfully added record 2024-T4W-069
# ..successfully added record 2024-T4W-070
# ..successfully added record 2024-T4W-073
# ..successfully added record 2024-T4W-075
# ..successfully added record 2024-T4W-076
# ..successfully added record 2024-T4W-077
# ..successfully added record 2024-T4W-079
# ..successfully added record 2024-T4W-080
# ..successfully added record 2024-T4W-081
# ..successfully added record 2024-T4W-082
# ..successfully added record 2024-T4W-083
# ..successfully added record 2024-T4W-086
# ..successfully added record 2024-T4W-089
# ..successfully added record 2024-T4W-090
# ..successfully added record 2024-T4W-091
# ..successfully added record 2024-T4W-093
# ..successfully added record 2024-T4W-094
# ..successfully added record 2024-T4W-095
# ..successfully added record 2024-T4W-097
# ..successfully added record 2024-T4W-098
# ..successfully added record 2024-T4W-099
# ..successfully added record 2024-T4W-104
# ..successfully added record 2024-T4W-105
# ..successfully added record 2024-T4W-106
# ..successfully added record 2024-T4W-108
# ..successfully added record 2024-T4W-109
# ..successfully added record 2024-T4W-111
# ..successfully added record 2024-T4W-112
# ..successfully added record 2024-T4W-113
# ..successfully added record 2024-T4W-114
# ..successfully added record 2024-T4W-115
# ..successfully added record 2024-T4W-116
# ..successfully added record 2024-T4W-117
# ..successfully added record 2024-T4W-HCTF19
# ..successfully added record 2024-T4W-HCTF03
# ..successfully added record 2023-T4W-HCTF18
# ..successfully added record 2024-T4W-HCTF30
# ..successfully added record 2024-T4W-HCTF16
# ..successfully added record 2024-T4W-HCTF26
# ..successfully added record 2023-T4W-HCTF07
# ..successfully added record 2024-T4W-HCTF35
# ..successfully added record 2024-T4W-HCTF28
# ..successfully added record 2023-T4W-HCTF14
# ..successfully added record 2024-T4W-HCTF36
# ..successfully added record 2024-T4W-HCTF01
# ..successfully added record 2023-T4W-HCTF20
# ..successfully added record 2024-T4W-HCTF32
# ..successfully added record 2023-T4W-HCTF02
# ..successfully added record 2023-T4W-HCTF03
# ..successfully added record 2023-T4W-HCTF13
# ..successfully added record 2024-T4W-HCTF15
# ..successfully added record 2023-T4W-HCTF23
# ..successfully added record 2024-T4W-HCTF34
# ..successfully added record 2024-T4W-HCTF31
# ..successfully added record 2024-T4W-HCTF04
# ..successfully added record 2023-T4W-HCTF16
# ..successfully added record 2024-T4W-HCTF29
# ..successfully added record 2024-T4W-HCTF33
# ..successfully added record 2023-T4W-HCTF21
# ..successfully added record 2023-T4W-HCTF24
# ..successfully added record 2023-T4W-HCTF10
# ..successfully added record 2023-T4W-HCTF04
# ..successfully added record 2023-T4W-HCTF17
# ..successfully added record 2024-T4W-HCTF25
# ..successfully added record 2024-T4W-HCTF37
# ..successfully added record 2023-T4W-HCTF05
# ..successfully added record 2024-T4W-HCTF22
# ..successfully added record 2024-T4W-HCTF27
# ..successfully added record 2024-T4W-HCTF20
# ..successfully added record 2023-T4W-HCTF22
# ..successfully added record 2023-T4W-HCTF19
# ..successfully added record 2023-T4W-HCTF15
#
# ..all records uploaded successfully.
